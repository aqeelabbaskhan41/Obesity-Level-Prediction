# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('ObesityDataSet.csv')
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight  \
# 0  Female  21.0    1.62    64.0                            yes
# 1  Female  21.0    1.52    56.0                            yes
# 2    Male  23.0    1.80    77.0                            yes
# 3    Male  27.0    1.80    87.0                             no
# 4    Male  22.0    1.78    89.8                             no
#
#   high_caloric_food  use_vegetables  num_meals_daily food_bw_meals smoking  \
# 0                no             2.0              3.0     Sometimes      no
# 1                no             3.0              3.0     Sometimes     yes
# 2                no             2.0              3.0     Sometimes      no
# 3                no             3.0              3.0     Sometimes      no
# 4                no             2.0              1.0     Sometimes      no
#
#    CH2O monitor_num_calories  physical_activity  use_technological_devices  \
# ...

# %%
df.tail()
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      high_caloric_food  use_vegetables  num_meals_daily food_bw_meals smoking  \
# 2106               yes             3.0              3.0     Sometimes      no
# 2107               yes             3.0              3.0     Sometimes      no
# 2108               yes             3.0              3.0     Sometimes      no
# 2109               yes             3.0              3.0     Sometimes      no
# 2110               yes             3.0              3.0     Sometimes      no
#
# ...

# %%
df.shape
# Out:
# (2111, 17)

# %%
df.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# high_caloric_food                 0
# use_vegetables                    0
# num_meals_daily                   0
# food_bw_meals                     0
# smoking                           0
# CH2O                              0
# monitor_num_calories              0
# physical_activity                 0
# use_technological_devices         0
# alcohol                           0
# traveling                         0
# obesity_level                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 24

# %% [markdown]
# # Dropping the duplicate values:
# * here 24 duplicates exists

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight  \
# 0  Female  21.0    1.62    64.0                            yes
# 1  Female  21.0    1.52    56.0                            yes
# 2    Male  23.0    1.80    77.0                            yes
# 3    Male  27.0    1.80    87.0                             no
# 4    Male  22.0    1.78    89.8                             no
#
#   high_caloric_food  use_vegetables  num_meals_daily food_bw_meals smoking  \
# 0                no             2.0              3.0     Sometimes      no
# 1                no             3.0              3.0     Sometimes     yes
# 2                no             2.0              3.0     Sometimes      no
# 3                no             3.0              3.0     Sometimes      no
# 4                no             2.0              1.0     Sometimes      no
#
#    CH2O monitor_num_calories  physical_activity  use_technological_devices  \
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       index  Gender        Age    Height      Weight  \
# 0         0  Female  21.000000  1.620000   64.000000
# 1         1  Female  21.000000  1.520000   56.000000
# 2         2    Male  23.000000  1.800000   77.000000
# 3         3    Male  27.000000  1.800000   87.000000
# 4         4    Male  22.000000  1.780000   89.800000
# ...     ...     ...        ...       ...         ...
# 2082   2106  Female  20.976842  1.710730  131.408528
# 2083   2107  Female  21.982942  1.748584  133.742943
# 2084   2108  Female  22.524036  1.752206  133.689352
# 2085   2109  Female  24.361936  1.739450  133.346641
# 2086   2110  Female  23.664709  1.738836  133.472641
#
#      family_history_with_overweight high_caloric_food  use_vegetables  \
# 0                               yes                no             2.0
# 1                               yes                no             3.0
# 2                               yes                no             2.0
# ...

# %%
df.columns
# Out:
# Index(['index', 'Gender', 'Age', 'Height', 'Weight',
#        'family_history_with_overweight', 'high_caloric_food', 'use_vegetables',
#        'num_meals_daily', 'food_bw_meals', 'smoking', 'CH2O',
#        'monitor_num_calories', 'physical_activity',
#        'use_technological_devices', 'alcohol', 'traveling', 'obesity_level'],
#       dtype='object')

# %%
df.sample(10)
# Out:
#       index  Gender        Age    Height      Weight  \
# 1137   1161    Male  18.181821  1.662669   79.863546
# 1843   1867  Female  26.000000  1.624390  110.008636
# 1268   1292    Male  23.887569  1.657995   90.000000
# 1130   1154    Male  22.882558  1.793451   89.909259
# 1710   1734    Male  30.717727  1.767140  120.344402
# 847     868  Female  21.837058  1.558045   63.597633
# 32       32  Female  24.000000  1.770000   76.000000
# 473     482  Female  20.000000  1.580000   53.500000
# 789     804    Male  26.758516  1.801790   86.981202
# 1575   1599    Male  20.184451  1.701284  104.578255
#
#      family_history_with_overweight high_caloric_food  use_vegetables  \
# 1137                            yes                no        2.492758
# 1843                            yes               yes        3.000000
# 1268                            yes               yes        2.000000
# 1130                            yes               yes        1.899116
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2087 entries, 0 to 2086
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   index                           2087 non-null   int64
#  1   Gender                          2087 non-null   object
#  2   Age                             2087 non-null   float64
#  3   Height                          2087 non-null   float64
#  4   Weight                          2087 non-null   float64
#  5   family_history_with_overweight  2087 non-null   object
#  6   high_caloric_food               2087 non-null   object
#  7   use_vegetables                  2087 non-null   float64
#  8   num_meals_daily                 2087 non-null   float64
#  9   food_bw_meals                   2087 non-null   object
#  10  smoking                         2087 non-null   object
#  11  CH2O                            2087 non-null   float64
# ...

# %%
df.describe()
# Out:
#              index          Age       Height       Weight  use_vegetables  \
# count  2087.000000  2087.000000  2087.000000  2087.000000     2087.000000
# mean   1060.516052    24.353090     1.702674    86.858730        2.421466
# std     610.062653     6.368801     0.093186    26.190847        0.534737
# min       0.000000    14.000000     1.450000    39.000000        1.000000
# 25%     532.500000    19.915937     1.630178    66.000000        2.000000
# 50%    1067.000000    22.847618     1.701584    83.101100        2.396265
# 75%    1588.500000    26.000000     1.769491   108.015907        3.000000
# max    2110.000000    61.000000     1.980000   173.000000        3.000000
#
#        num_meals_daily         CH2O  physical_activity  \
# count      2087.000000  2087.000000        2087.000000
# mean          2.701179     2.004749           1.012812
# std           0.764614     0.608284           0.853475
# min           1.000000     1.000000           0.000000
# ...

# %%
df.nunique()
# Out:
# index                             2087
# Gender                               2
# Age                               1402
# Height                            1574
# Weight                            1525
# family_history_with_overweight       2
# high_caloric_food                    2
# use_vegetables                     810
# num_meals_daily                    635
# food_bw_meals                        4
# smoking                              2
# CH2O                              1268
# monitor_num_calories                 2
# physical_activity                 1190
# use_technological_devices         1129
# alcohol                              4
# traveling                            5
# obesity_level                        7
# dtype: int64

# %%
df['traveling'].unique()
# Out:
# array(['Public_Transportation', 'Walking', 'Automobile', 'Motorbike',
#        'Bike'], dtype=object)

# %%
# corelation = df.corr()

# %%
df[['Age','Height']].corr()
# Out:
#              Age    Height
# Age     1.000000 -0.031748
# Height -0.031748  1.000000

# %% [markdown]
# # Analysis

# %% [markdown]
# ## 1.Catagorical

# %%
df.head()
# Out:
#    index  Gender   Age  Height  Weight family_history_with_overweight  \
# 0      0  Female  21.0    1.62    64.0                            yes
# 1      1  Female  21.0    1.52    56.0                            yes
# 2      2    Male  23.0    1.80    77.0                            yes
# 3      3    Male  27.0    1.80    87.0                             no
# 4      4    Male  22.0    1.78    89.8                             no
#
#   high_caloric_food  use_vegetables  num_meals_daily food_bw_meals smoking  \
# 0                no             2.0              3.0     Sometimes      no
# 1                no             3.0              3.0     Sometimes     yes
# 2                no             2.0              3.0     Sometimes      no
# 3                no             3.0              3.0     Sometimes      no
# 4                no             2.0              1.0     Sometimes      no
#
#    CH2O monitor_num_calories  physical_activity  use_technological_devices  \
# ...

# %%
plt.figure(figsize=(4,3))
sns.countplot(data=df, x='Gender', hue='Gender')
df['Gender'].value_counts()
# Out:
# Gender
# Male      1052
# Female    1035
# Name: count, dtype: int64

# %%
# count plot for checking genders ratio
# sns.countplot(df['Gender'], color='orange')
# df['Gender'].value_counts()
plt.figure(figsize=(4,3))
sns.countplot(data=df, x='family_history_with_overweight', hue='family_history_with_overweight')
df['family_history_with_overweight'].value_counts()
# Out:
# family_history_with_overweight
# yes    1722
# no      365
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,4))
sns.countplot(data=df, x='food_bw_meals', hue='food_bw_meals')
# Out:
# <Axes: xlabel='food_bw_meals', ylabel='count'>

# %%
plt.figure(figsize=(4,3))
sns.countplot(data=df, x='smoking', hue='smoking')
df['smoking'].value_counts()
# Out:
# smoking
# no     2043
# yes      44
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))
df['alcohol'].value_counts().plot(kind='pie' ,autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['obesity_level'].value_counts().plot(kind='pie' ,autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(5,4))
sns.countplot(data=df, x='monitor_num_calories', hue='monitor_num_calories')
# Out:
# <Axes: xlabel='monitor_num_calories', ylabel='count'>

# %%
df['traveling'].value_counts().plot(kind='barh' )
# Out:
# <Axes: ylabel='traveling'>

# %%
plt.figure(figsize=(18,16))
df['traveling'].value_counts().plot(kind='pie', autopct='%.2f' )
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(5,4))
sns.pairplot(df[["Age", "CH2O", "Height", "Weight", "Gender"]])

# %% [markdown]
# ## Numerical

# %%
# setting the grid style 
sns.set_style('whitegrid')

# %%
# plt.hist(data=df, x='Age', bins=20)
plt.figure(figsize=(5,4))
sns.histplot(data=df, x='Age', bins=20, color='red')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(5,4))
sns.displot(data=df, x='Age', kind='hist')

# %%
plt.figure(figsize=(5,4))
sns.set_style('whitegrid')
sns.displot(data=df, x='Age', kind='kde')

# %%
df.head(10)
# Out:
#    index  Gender   Age  Height  Weight family_history_with_overweight  \
# 0      0  Female  21.0    1.62    64.0                            yes
# 1      1  Female  21.0    1.52    56.0                            yes
# 2      2    Male  23.0    1.80    77.0                            yes
# 3      3    Male  27.0    1.80    87.0                             no
# 4      4    Male  22.0    1.78    89.8                             no
# 5      5    Male  29.0    1.62    53.0                             no
# 6      6  Female  23.0    1.50    55.0                            yes
# 7      7    Male  22.0    1.64    53.0                             no
# 8      8    Male  24.0    1.78    64.0                            yes
# 9      9    Male  22.0    1.72    68.0                            yes
#
#   high_caloric_food  use_vegetables  num_meals_daily food_bw_meals smoking  \
# 0                no             2.0              3.0     Sometimes      no
# ...

# %%
plt.figure(figsize=(5,4))
sns.boxplot(data=df, x='Weight')
# Out:
# <Axes: xlabel='Weight'>

# %%
df['Weight'].max() # it means there is one outlier or highly weighted
# Out:
# 173.0

# %%
# df['use_vegetables'].unique()

# %%
plt.figure(figsize=(5,4))
sns.histplot(data=df, x='use_vegetables', bins=20)
# Out:
# <Axes: xlabel='use_vegetables', ylabel='Count'>

# %%
plt.figure(figsize=(5,4))
sns.displot(data=df, x='num_meals_daily')
# sns.countplot(data=df, x='num_meals_daily')

# %%
plt.figure(figsize=(5,4))
sns.histplot(data=df, x='num_meals_daily')
# Out:
# <Axes: xlabel='num_meals_daily', ylabel='Count'>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (2087, 18)

# %%
df.head()
# Out:
#    index  Gender   Age  Height  Weight family_history_with_overweight  \
# 0      0  Female  21.0    1.62    64.0                            yes
# 1      1  Female  21.0    1.52    56.0                            yes
# 2      2    Male  23.0    1.80    77.0                            yes
# 3      3    Male  27.0    1.80    87.0                             no
# 4      4    Male  22.0    1.78    89.8                             no
#
#   high_caloric_food  use_vegetables  num_meals_daily food_bw_meals smoking  \
# 0                no             2.0              3.0     Sometimes      no
# 1                no             3.0              3.0     Sometimes     yes
# 2                no             2.0              3.0     Sometimes      no
# 3                no             3.0              3.0     Sometimes      no
# 4                no             2.0              1.0     Sometimes      no
#
#    CH2O monitor_num_calories  physical_activity  use_technological_devices  \
# ...

# %%
categorical_cols = [
    'Gender',
    'family_history_with_overweight',
    'high_caloric_food',
    'food_bw_meals',
    'smoking',
    'monitor_num_calories',
    'alcohol',
    'traveling'
]


numerical_cols = [
    'Age',
    'Height',
    'Weight',
    'use_vegetables',
    'num_meals_daily',
    'CH2O',
    'physical_activity',
    'use_technological_devices'
]

target_col = 'obesity_level'

# %%
len(categorical_cols), len(numerical_cols)
# Out:
# (8, 8)

# %%
df[categorical_cols].head(5)
# Out:
#    Gender family_history_with_overweight high_caloric_food food_bw_meals  \
# 0  Female                            yes                no     Sometimes
# 1  Female                            yes                no     Sometimes
# 2    Male                            yes                no     Sometimes
# 3    Male                             no                no     Sometimes
# 4    Male                             no                no     Sometimes
#
#   smoking monitor_num_calories     alcohol              traveling
# 0      no                   no          no  Public_Transportation
# 1     yes                  yes   Sometimes  Public_Transportation
# 2      no                   no  Frequently  Public_Transportation
# 3      no                   no  Frequently                Walking
# 4      no                   no   Sometimes  Public_Transportation

# %%
df[numerical_cols].head(5)
# Out:
#     Age  Height  Weight  use_vegetables  num_meals_daily  CH2O  \
# 0  21.0    1.62    64.0             2.0              3.0   2.0
# 1  21.0    1.52    56.0             3.0              3.0   3.0
# 2  23.0    1.80    77.0             2.0              3.0   2.0
# 3  27.0    1.80    87.0             3.0              3.0   2.0
# 4  22.0    1.78    89.8             2.0              1.0   2.0
#
#    physical_activity  use_technological_devices
# 0                0.0                        1.0
# 1                3.0                        0.0
# 2                2.0                        1.0
# 3                2.0                        0.0
# 4                0.0                        0.0

# %%
df[numerical_cols].sample(5)
# Out:
#             Age    Height      Weight  use_vegetables  num_meals_daily  \
# 1630  24.582200  1.769933  117.708705        1.475906         2.999346
# 1306  24.317607  1.586751   79.109029        2.000000         1.000000
# 957   32.774488  1.913241  101.482054        2.000000         2.110937
# 233   19.000000  1.700000   64.000000        3.000000         3.000000
# 1670  30.605464  1.754796  118.805937        2.907542         3.000000
#
#           CH2O  physical_activity  use_technological_devices
# 1630  2.019430           1.046878                   0.460866
# 1306  2.000000           0.852446                   0.000000
# 957   2.175632           1.000000                   0.000000
# 233   3.000000           3.000000                   1.000000
# 1670  2.284494           0.647632                   1.668318

# %%
plt.figure(figsize=(15, 6))
sns.countplot(data=df, x=target_col, hue=target_col)
# Out:
# <Axes: xlabel='obesity_level', ylabel='count'>

# %%
for col in numerical_cols:
    plt.figure(figsize=(15, 6))
    sns.boxplot(x=target_col, y=col, data=df, hue=target_col)
    plt.title(f'Boxplot of {col} by {target_col}')
    plt.show()

# %%
for col in categorical_cols:
    plt.figure(figsize=(15, 6))
    sns.countplot(data=df, x=col, hue='obesity_level')
    plt.title(f'Distribution of {col} by Obesity Level')
    plt.show()

# %%
df[numerical_cols].corr()
# Out:
#                                 Age    Height    Weight  use_vegetables  \
# Age                        1.000000 -0.031748  0.198160        0.013572
# Height                    -0.031748  1.000000  0.457468       -0.040363
# Weight                     0.198160  0.457468  1.000000        0.216574
# use_vegetables             0.013572 -0.040363  0.216574        1.000000
# num_meals_daily           -0.055823  0.227806  0.092149        0.034885
# CH2O                      -0.044058  0.220487  0.203823        0.081332
# physical_activity         -0.148202  0.293584 -0.056490        0.022003
# use_technological_devices -0.302927  0.041808 -0.079351       -0.104128
#
#                            num_meals_daily      CH2O  physical_activity  \
# Age                              -0.055823 -0.044058          -0.148202
# Height                            0.227806  0.220487           0.293584
# Weight                            0.092149  0.203823          -0.056490
# ...

# %%
sns.heatmap(df[numerical_cols].corr(), annot=True)
# Out:
# <Axes: >

# %%
plt.hist(data=df, x='Age', bins=20)
# Out:
# (array([ 18., 296., 461., 428., 214., 242.,  92.,  98.,  71.,  37.,  66.,
#          35.,  12.,   5.,   2.,   2.,   1.,   6.,   0.,   1.]),
#  array([14.  , 16.35, 18.7 , 21.05, 23.4 , 25.75, 28.1 , 30.45, 32.8 ,
#         35.15, 37.5 , 39.85, 42.2 , 44.55, 46.9 , 49.25, 51.6 , 53.95,
#         56.3 , 58.65, 61.  ]),
#  <BarContainer object of 20 artists>)

# %%
sns.histplot(data=df, x='Age', bins=20)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
plt.scatter(data=df.sample(500), x='Height',y='Weight')

# %% [markdown]
# ## Outlier detection and removal

# %%
import scipy.stats as stats

# QQ plot for Age before transformation
plt.figure(figsize=(12, 6))
stats.probplot(df['Age'], dist="norm", plot=plt)
plt.title('QQ Plot of Age (Before Transformation)')
# Out:
# Text(0.5, 1.0, 'QQ Plot of Age (Before Transformation)')

# %% [markdown]
# Logarithmic transformation on age

# %%
df['Age'] = np.log1p(df['Age'])  # Logarithmic transformation
sns.histplot(data=df, x='Age', bins=20, kde=True)
plt.title('Transformed Age Distribution')
plt.show()

# %%
# Recalculate outliers for the transformed Age column
Q1 = df['Age'].quantile(0.25)
Q3 = df['Age'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_age_transformed = df[(df['Age'] < lower_bound) | (df['Age'] > upper_bound)]
outlier_count_age_transformed = len(outliers_age_transformed)

print(f"Number of outliers in transformed Age: {outlier_count_age_transformed}")
# Out:
# Number of outliers in transformed Age: 93

# %%
# Remove outliers from the Age column
df = df[(df['Age'] >= lower_bound) & (df['Age'] <= upper_bound)].reset_index(drop=True)

# Display the updated DataFrame shape
print(df.shape)
# Out:
# (1994, 18)

# %%
# QQ plot for Age after transformation
stats.probplot(df['Age'], dist="norm", plot=plt)
plt.title('QQ Plot of Age (After Transformation)')
plt.tight_layout()
plt.show()

# %%
Q1 = df['Height'].quantile(0.25)
Q3 = df["Height"].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
count = 0
for i in df['Height']:
    if(i<lower_bound or i>upper_bound):
        count= count+1
print(count)
# Out:
# 2

# %%
Q1 = df['Weight'].quantile(0.25)
Q3 = df["Weight"].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
count = 0
for i in df['Weight']:
    if(i<lower_bound or i>upper_bound):
        count= count+1
print(count)
# Out:
# 0

# %%
Q1 = df['CH2O'].quantile(0.25)
Q3 = df["CH2O"].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
count = 0
for i in df['CH2O']:
    if(i<lower_bound or i>upper_bound):
        count= count+1
print(count)
# Out:
# 0

# %%
sns.histplot(data=df, x='Age', bins=20)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=df, x='Height', bins=20)
# Out:
# <Axes: xlabel='Height', ylabel='Count'>

# %%
sns.histplot(data=df, x='Weight')
# Out:
# <Axes: xlabel='Weight', ylabel='Count'>

# %%
from sklearn.preprocessing import RobustScaler

# Apply RobustScaler to normalize 'num_meals_daily'
scaler = RobustScaler()
df['num_meals_daily'] = scaler.fit_transform(df[['num_meals_daily']])

# Plot the normalized column to visualize the effect
sns.histplot(data=df, x='num_meals_daily', bins=20)
plt.title('Normalized num_meals_daily Distribution')
plt.show()

# %%
outlier_counts = {}

for col in numerical_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    outlier_counts[col] = len(outliers)

print(outlier_counts)
# Out:
# {'Age': 0, 'Height': 2, 'Weight': 0, 'use_vegetables': 0, 'num_meals_daily': 552, 'CH2O': 0, 'physical_activity': 0, 'use_technological_devices': 0}

# %%
df.shape
# Out:
# (1994, 18)

# %%
# After removing outliers
sns.boxplot(data=df, x='Age')
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# ## feature construction

# %%
# Calculate BMI
df['BMI'] = df['Weight'] / (df['Height'] ** 2)

# Drop the Weight and Height columns
df.drop(columns=['Weight', 'Height'], inplace=True)

df.drop(columns='index', inplace=True)
# Display the updated DataFrame
df.head()
# Out:
#    Gender       Age family_history_with_overweight high_caloric_food  \
# 0  Female  3.091042                            yes                no
# 1  Female  3.091042                            yes                no
# 2    Male  3.178054                            yes                no
# 3    Male  3.332205                             no                no
# 4    Male  3.135494                             no                no
#
#    use_vegetables  num_meals_daily food_bw_meals smoking  CH2O  \
# 0             2.0         0.000000     Sometimes      no   2.0
# 1             3.0         0.000000     Sometimes     yes   3.0
# 2             2.0         0.000000     Sometimes      no   2.0
# 3             3.0         0.000000     Sometimes      no   2.0
# 4             2.0        -6.657446     Sometimes      no   2.0
#
#   monitor_num_calories  physical_activity  use_technological_devices  \
# 0                   no                0.0                        1.0
# ...

# %%
# updating the numerical columns list to include BMI
numerical_cols = [
    'Age',
    'BMI',
    'use_vegetables',
    'num_meals_daily',
    'CH2O',
    'physical_activity',
    'use_technological_devices'
]

# %%
# Use all features from the dataset
X = df.drop(columns=[target_col])  # Exclude the target column
y = df[target_col]  # Target column

# %%
X.head()
# Out:
#    Gender       Age family_history_with_overweight high_caloric_food  \
# 0  Female  3.091042                            yes                no
# 1  Female  3.091042                            yes                no
# 2    Male  3.178054                            yes                no
# 3    Male  3.332205                             no                no
# 4    Male  3.135494                             no                no
#
#    use_vegetables  num_meals_daily food_bw_meals smoking  CH2O  \
# 0             2.0         0.000000     Sometimes      no   2.0
# 1             3.0         0.000000     Sometimes     yes   3.0
# 2             2.0         0.000000     Sometimes      no   2.0
# 3             3.0         0.000000     Sometimes      no   2.0
# 4             2.0        -6.657446     Sometimes      no   2.0
#
#   monitor_num_calories  physical_activity  use_technological_devices  \
# 0                   no                0.0                        1.0
# ...

# %% [markdown]
# Encoding catagorical data

# %%
# Perform one-hot encoding on categorical columns
encoded_categorical = pd.get_dummies(X[categorical_cols], drop_first=True, dtype=int)

# Drop the original categorical columns from X
X = X.drop(columns=categorical_cols)
# Concatenate the encoded categorical columns back to X
X = pd.concat([X, encoded_categorical], axis=1)

# %%
X.head()
# Out:
#         Age  use_vegetables  num_meals_daily  CH2O  physical_activity  \
# 0  3.091042             2.0         0.000000   2.0                0.0
# 1  3.091042             3.0         0.000000   3.0                3.0
# 2  3.178054             2.0         0.000000   2.0                2.0
# 3  3.332205             3.0         0.000000   2.0                2.0
# 4  3.135494             2.0        -6.657446   2.0                0.0
#
#    use_technological_devices        BMI  Gender_Male  \
# 0                        1.0  24.386526            0
# 1                        0.0  24.238227            0
# 2                        1.0  23.765432            1
# 3                        0.0  26.851852            1
# 4                        0.0  28.342381            1
#
#    family_history_with_overweight_yes  high_caloric_food_yes  ...  \
# 0                                   1                      0  ...
# 1                                   1                      0  ...
# ...

# %% [markdown]
# Numerical Feature Scaling

# %%
# Scale the numerical columns
scaler = StandardScaler()
X[numerical_cols] = scaler.fit_transform(X[numerical_cols])

# %%
X.head()
# Out:
#         Age  use_vegetables  num_meals_daily      CH2O  physical_activity  \
# 0 -0.458052       -0.787962         0.387607 -0.014691          -1.201111
# 1 -0.458052        1.062931         0.387607  1.636239           2.324961
# 2 -0.008186       -0.787962         0.387607 -0.014691           1.149604
# 3  0.788805        1.062931         0.387607 -0.014691           1.149604
# 4 -0.228227       -0.787962        -2.230910 -0.014691          -1.201111
#
#    use_technological_devices       BMI  Gender_Male  \
# 0                   0.517125 -0.652922            0
# 1                  -1.127965 -0.671104            0
# 2                   0.517125 -0.729071            1
# 3                  -1.127965 -0.350662            1
# 4                  -1.127965 -0.167916            1
#
#    family_history_with_overweight_yes  high_caloric_food_yes  ...  \
# 0                                   1                      0  ...
# 1                                   1                      0  ...
# ...

# %% [markdown]
# Label Encoding

# %%
# Encode the target column
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %%
y
# Out:
# array([1, 1, 1, ..., 4, 4, 4])

# %%
X.head()
# Out:
#         Age  use_vegetables  num_meals_daily      CH2O  physical_activity  \
# 0 -0.458052       -0.787962         0.387607 -0.014691          -1.201111
# 1 -0.458052        1.062931         0.387607  1.636239           2.324961
# 2 -0.008186       -0.787962         0.387607 -0.014691           1.149604
# 3  0.788805        1.062931         0.387607 -0.014691           1.149604
# 4 -0.228227       -0.787962        -2.230910 -0.014691          -1.201111
#
#    use_technological_devices       BMI  Gender_Male  \
# 0                   0.517125 -0.652922            0
# 1                  -1.127965 -0.671104            0
# 2                   0.517125 -0.729071            1
# 3                  -1.127965 -0.350662            1
# 4                  -1.127965 -0.167916            1
#
#    family_history_with_overweight_yes  high_caloric_food_yes  ...  \
# 0                                   1                      0  ...
# 1                                   1                      0  ...
# ...

# %%
X.head()
# Out:
#         Age  use_vegetables  num_meals_daily      CH2O  physical_activity  \
# 0 -0.458052       -0.787962         0.387607 -0.014691          -1.201111
# 1 -0.458052        1.062931         0.387607  1.636239           2.324961
# 2 -0.008186       -0.787962         0.387607 -0.014691           1.149604
# 3  0.788805        1.062931         0.387607 -0.014691           1.149604
# 4 -0.228227       -0.787962        -2.230910 -0.014691          -1.201111
#
#    use_technological_devices       BMI  Gender_Male  \
# 0                   0.517125 -0.652922            0
# 1                  -1.127965 -0.671104            0
# 2                   0.517125 -0.729071            1
# 3                  -1.127965 -0.350662            1
# 4                  -1.127965 -0.167916            1
#
#    family_history_with_overweight_yes  high_caloric_food_yes  ...  \
# 0                                   1                      0  ...
# 1                                   1                      0  ...
# ...

# %%
X.shape
# Out:
# (1994, 22)

# %%
y
# Out:
# array([1, 1, 1, ..., 4, 4, 4])

# %% [markdown]
# Saving preprocessed data into csv file

# %%
# Combine X and y into a single DataFrame for saving
final_df = X.copy()
final_df[target_col] = y
# final_df.to_csv('final preprocessed and cleaned data.csv', index=False)
